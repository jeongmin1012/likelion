# %%
import time
from tqdm import tqdm

# %%
a1 = 0

for v1 in tqdm(range(20)) :
    # 1초 쉰다 (1초 이상 걸리는 작업이 있다고 가정한다.)
    time.sleep(1)
    a1 = a1 + 1

print(a1)
# Out:
# 100%|██████████| 20/20 [00:20<00:00,  1.01s/it]
# 20
