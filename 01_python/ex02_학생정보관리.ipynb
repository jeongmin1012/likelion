# %% [raw]
# 학생 정보를 출력하는 프로그램
# 출력은 다음과 같이 한다.
#
# 이름 : 홍길동
# 나이 : 10 살
# 국어점수 : 70 점
# 영어점수 : 71 점
# 수학점수 : 72 점
#
# 이름 : 김길동
# 나이 : 11 살
# 국어점수 : 80 점
# 영어점수 : 81 점
# 수학점수 : 82 점
#
# 이름 : 최길동
# 나이 : 12 살
# 국어점수 : 90 점
# 영어점수 : 91 점
# 수학점수 : 92 점
#
# 학생의 이름과, 나이, 각 과목별 점수를 입력받아 출력한다.

# %%
#1번학생 정보 입력(홍길동)
name1=input('1번 학생 이름을 입력해주세요.')
age1=input('1번 학생의 나이를 입력해주세요.(숫자만)')
kor1=input('1번 학생의 국어점수를 입력해주세요.(숫자만)')
eng1=input('1번 학생의 영어점수를 입력해주세요.(숫자만)')
math1=input('1번 학생의 수학점수를 입력해주세요.(숫자만)')
#2번학생 정보 입력(김길동)
name2=input('2번 학생 이름을 입력해주세요.')
age2=input('2번 학생의 나이를 입력해주세요.(숫자만)')
kor2=input('2번 학생의 국어점수를 입력해주세요.(숫자만)')
eng2=input('2번 학생의 영어점수를 입력해주세요.(숫자만)')
math2=input('2번 학생의 수학점수를 입력해주세요.(숫자만)')
#3번학생 정보 입력(최길동)
name3=input('3번 학생 이름을 입력해주세요.')
age3=input('3번 학생의 나이를 입력해주세요.(숫자만)')
kor3=input('3번 학생의 국어점수를 입력해주세요.(숫자만)')
eng3=input('3번 학생의 영어점수를 입력해주세요.(숫자만)')
math3=input('3번 학생의 수학점수를 입력해주세요.(숫자만)')

#학생 정보출력
print('이름 :',name1)
print('나이 :',age1,'살')
print('국어점수 :',kor1,'점')
print('영어점수 :',eng1,'점')
print('수학점수 :',math1,'점')
print()
print('이름 :',name2)
print('나이 :',age2,'살')
print('국어점수 :',kor2,'점')
print('영어점수 :',eng2,'점')
print('수학점수 :',math2,'점')
print()
print('이름 :',name3)
print('나이 :',age3,'살')
print('국어점수 :',kor3,'점')
print('영어점수 :',eng3,'점')
print('수학점수 :',math3,'점')
print()
# Out:
# 이름 : 홍길동
# 나이 : 10 살
# 국어점수 : 70 점
# 영어점수 : 71 점
# 수학점수 : 72 점
#
# 이름 : 김길동
# 나이 : 11 살
# 국어점수 : 80 점
# 영어점수 : 81 점
# 수학점수 : 82 점
#
# 이름 : 최길동
# 나이 : 12 살
# 국어점수 : 90 점
# 영어점수 : 91 점
# 수학점수 : 92 점

# %% [markdown]
# ---

# %% [markdown]
# ### teacher's version

# %%
# 필요한 데이터를 준비한다.
# 사용자에게 데이터를 입력받는다.
name1 = input('이름을 입력해주세요')
age1 = input('나이를 입력해주세요')
kor1 = input('국어점수를 입력해주세요')
eng1 = input('영어점수를 입력해주세요')
math1 = input('수학점수를 입력해주세요')

name2 = input('이름을 입력해주세요')
age2 = input('나이를 입력해주세요')
kor2 = input('국어점수를 입력해주세요')
eng2 = input('영어점수를 입력해주세요')
math2 = input('수학점수를 입력해주세요')

name3 = input('이름을 입력해주세요')
age3 = input('나이를 입력해주세요')
kor3 = input('국어점수를 입력해주세요')
eng3 = input('영어점수를 입력해주세요')
math3 = input('수학점수를 입력해주세요')

# 데이터를 통해 처리를 한다.

# 처리된 결과를 출력한다.
print('이름 :', name1)
print('나이 :', age1, '살')
print('국어점수 :', kor1, '점')
print('영어점수 :', eng1, '점')
print('수학점수 :', math1, '점')
print()

print('이름 :', name2)
print('나이 :', age2, '살')
print('국어점수 :', kor2, '점')
print('영어점수 :', eng2, '점')
print('수학점수 :', math2, '점')
print()

print('이름 :', name3)
print('나이 :', age3, '살')
print('국어점수 :', kor3, '점')
print('영어점수 :', eng3, '점')
print('수학점수 :', math3, '점')
