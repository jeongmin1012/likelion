# %% [raw]
# 학생 정보를 출력하는 프로그램
# 출력은 다음과 같이 한다.
#
# 이름 : 홍길동
# 나이 : 10 살
# 국어점수 : 70 점
# 영어점수 : 71 점
# 수학점수 : 72 점
#
# 이름 : 김길동
# 나이 : 11 살
# 국어점수 : 80 점
# 영어점수 : 81 점
# 수학점수 : 82 점
#
# 이름 : 최길동
# 나이 : 12 살
# 국어점수 : 90 점
# 영어점수 : 91 점
# 수학점수 : 92 점
#
# 학생의 이름과, 나이, 각 과목별 점수를 입력받아 출력한다.
#
# 입력받은 데이터를 리스트에 담아 관리한다.

# %%
#학생 정보 입력 - 리스트로

#1번 학생(홍길동)
student1=[]
student1.append(input('1번 학생의 이름을 입력하세요'))
student1.append(int(input('1번 학생의 나이를 입력해주세요(숫자만)')))
student1.append(int(input('1번 학생의 국어점수를 입력해주세요(숫자만)')))
student1.append(int(input('1번 학생의 수학점수를 입력해주세요(숫자만)')))
student1.append(int(input('1번 학생의 영어점수를 입력해주세요(숫자만)')))

#2번 학생(김길동)
student2=[]
student2.append(input('2번 학생의 이름을 입력하세요'))
student2.append(int(input('2번 학생의 나이를 입력해주세요(숫자만)')))
student2.append(int(input('2번 학생의 국어점수를 입력해주세요(숫자만)')))
student2.append(int(input('2번 학생의 수학점수를 입력해주세요(숫자만)')))
student2.append(int(input('2번 학생의 영어점수를 입력해주세요(숫자만)')))

#3번 학생(최길동)
student3=[]
student3.append(input('2번 학생의 이름을 입력하세요'))
student3.append(int(input('2번 학생의 나이를 입력해주세요(숫자만)')))
student3.append(int(input('2번 학생의 국어점수를 입력해주세요(숫자만)')))
student3.append(int(input('2번 학생의 수학점수를 입력해주세요(숫자만)')))
student3.append(int(input('2번 학생의 영어점수를 입력해주세요(숫자만)')))

#출력
print('이름 :',student1[0])
print('나이 :',student1[1],'살')
print('국어점수 :',student1[2],'점')
print('영어점수 :',student1[3],'점')
print('수학점수 :',student1[4],'점')
print()
print('이름 :',student2[0])
print('나이 :',student2[1],'살')
print('국어점수 :',student2[2],'점')
print('영어점수 :',student2[3],'점')
print('수학점수 :',student2[4],'점')
print()
print('이름 :',student3[0])
print('나이 :',student3[1],'살')
print('국어점수 :',student3[2],'점')
print('영어점수 :',student3[3],'점')
print('수학점수 :',student3[4],'점')
print()
# Out:
# 이름 : 홍길동
# 나이 : 10 살
# 국어점수 : 70 점
# 영어점수 : 71 점
# 수학점수 : 72 점
#
# 이름 : 김길동
# 나이 : 11 살
# 국어점수 : 80 점
# 영어점수 : 81 점
# 수학점수 : 82 점
#
# 이름 : 최길동
# 나이 : 12 살
# 국어점수 : 90 점
# 영어점수 : 91 점
# 수학점수 : 92 점

# %%
#리스트 - 입력값 한꺼번에 받기

#1번 학생(홍길동)
student1=[]
student1.extend(input('1번 학생의 이름, 나이, 국어점수, 영어점수, 수학점수를 입력하세요(공백으로 구분)').split())

#2번 학생(김길동)
student2=[]
student2.extend(input('2번 학생의 이름, 나이, 국어점수, 영어점수, 수학점수를 입력하세요(공백으로 구분)').split())

#3번 학생(최길동)
student3=[]
student3.extend(input('1번 학생의 이름, 나이, 국어점수, 영어점수, 수학점수를 입력하세요(공백으로 구분)').split())

#정보 출력
print('이름 :',student1[0])
print('나이 :',student1[1],'살')
print('국어점수 :',student1[2],'점')
print('영어점수 :',student1[3],'점')
print('수학점수 :',student1[4],'점')
print()
print('이름 :',student2[0])
print('나이 :',student2[1],'살')
print('국어점수 :',student2[2],'점')
print('영어점수 :',student2[3],'점')
print('수학점수 :',student2[4],'점')
print()
print('이름 :',student3[0])
print('나이 :',student3[1],'살')
print('국어점수 :',student3[2],'점')
print('영어점수 :',student3[3],'점')
print('수학점수 :',student3[4],'점')
print()
# Out:
# 이름 : 홍길동
# 나이 : 10 살
# 국어점수 : 70 점
# 영어점수 : 71 점
# 수학점수 : 72 점
#
# 이름 : 김길동
# 나이 : 11 살
# 국어점수 : 80 점
# 영어점수 : 81 점
# 수학점수 : 82 점
#
# 이름 : 최길동
# 나이 : 12 살
# 국어점수 : 90 점
# 영어점수 : 91 점
# 수학점수 : 92 점

# %% [markdown]
# ### teacher's comment
# - 출력도 반복문을 사용하는 것으로 바꿔보세요
# - 리스트 하나 안에 다양한 의미를 값을 넣는 건 좋지 않습니다. 이 점도 고려해보세요.

# %%
#리스트 - 입력값 한꺼번에 받기

#1번 학생(홍길동)
student1=[]
student1.extend(input('1번 학생의 이름, 나이, 국어점수, 영어점수, 수학점수를 입력하세요(공백으로 구분)').split())

#2번 학생(김길동)
student2=[]
student2.extend(input('2번 학생의 이름, 나이, 국어점수, 영어점수, 수학점수를 입력하세요(공백으로 구분)').split())

#3번 학생(최길동)
student3=[]
student3.extend(input('1번 학생의 이름, 나이, 국어점수, 영어점수, 수학점수를 입력하세요(공백으로 구분)').split())

#정보 출력 _1번 코멘트 추가인데... 이렇게 해도 되는지는 의문 in 뒤에 직접적으로 변수 여러개를 입력하는건 안배웠음
for student in [student1, student2, student3]:
    print('이름 :', student[0])
    print('나이 :', student[1], '살')
    print('국어점수 :', student[2], '점')
    print('영어점수 :', student[3], '점')
    print('수학점수 :', student[4], '점')
    print()

# %% [markdown]
# ---

# %% [markdown]
# ### teacher's version

# %%
# 데이터를 담을 리스트
name_list = []
age_list = []
kor_list = []
eng_list = []
math_list = []

#학생 수
student_cnt = 3

# %%
# 3명의 학생 정보를 입력받는다.
# name_list[0] = input('이름을 입력해주세요')
# age_list[0] = input('나이를 입력해주세요')
# kor_list[0] = input('국어점수를 입력해주세요')
# eng_list[0] = input('영어점수를 입력해주세요')
# math_list[0] = input('수학점수를 입력해주세요')

# name_list[1] = input('이름을 입력해주세요')
# age_list[1] = input('나이를 입력해주세요')
# kor_list[1] = input('국어점수를 입력해주세요')
# eng_list[1] = input('영어점수를 입력해주세요')
# math_list[1] = input('수학점수를 입력해주세요')

# name_list[2] = input('이름을 입력해주세요')
# age_list[2] = input('나이를 입력해주세요')
# kor_list[2] = input('국어점수를 입력해주세요')
# eng_list[2] = input('영어점수를 입력해주세요')
# math_list[2] = input('수학점수를 입력해주세요')

# 학생 수 만큼 반복한다.
for order in range(student_cnt) :
    # 학생의 데이터를 입력받는다.
    name_list_temp = input('이름을 입력해주세요')
    age_list_temp = input('나이를 입력해주세요')
    kor_list_temp = input('국어점수를 입력해주세요')
    eng_list_temp = input('영어점수를 입력해주세요')
    math_list_temp = input('수학점수를 입력해주세요')

    # 입력받은 데이터를 리스트에 담는다
    name_list.append(name_list_temp)
    age_list.append(age_list_temp)
    kor_list.append(kor_list_temp)
    eng_list.append(eng_list_temp)
    math_list.append(math_list_temp)

# 각 학생들의 정보를 출력한다.
# print(f'이름 : {name_list[0]}')
# print(f'나이 : {age_list[0]}살')
# print(f'국어점수 : {kor_list[0]}점')
# print(f'영어점수 : {eng_list[0]}점')
# print(f'수학점수 : {math_list[0]}점')
# print()

# print(f'이름 : {name_list[1]}')
# print(f'나이 : {age_list[1]}살')
# print(f'국어점수 : {kor_list[1]}점')
# print(f'영어점수 : {eng_list[1]}점')
# print(f'수학점수 : {math_list[1]}점')
# print()

# print(f'이름 : {name_list[2]}')
# print(f'나이 : {age_list[2]}살')
# print(f'국어점수 : {kor_list[2]}점')
# print(f'영어점수 : {eng_list[2]}점')
# print(f'수학점수 : {math_list[2]}점')
# print()

# 학생의 수 만큼 반복한다.
for order in range(student_cnt) :
    # 출력한다.
    print(f'이름 : {name_list[order]}')
    print(f'나이 : {age_list[order]}살')
    print(f'국어점수 : {kor_list[order]}점')
    print(f'영어점수 : {eng_list[order]}점')
    print(f'수학점수 : {math_list[order]}점')
    print()
