# %%
from LikeLionLinearData import LikeLionStack
from LikeLionLinearData import LikeLionQueue
from LikeLionLinearData import LikeLionLinkedList
from LikeLionLinearData import LikeLionDoubleLinkedList

# %%
stack = LikeLionStack()

stack.push(10)
stack.showData()

stack.push(20)
stack.showData()

stack.push(30)
stack.showData()

a1 = stack.pop()
print(a1, end=' - ')
stack.showData()

a1 = stack.pop()
print(a1, end=' - ')
stack.showData()

a1 = stack.pop()
print(a1, end=' - ')
stack.showData()
# Out:
# [10]
# [10, 20]
# [10, 20, 30]
# 30 - [10, 20]
# 20 - [10]
# 10 - []

# %%
queue = LikeLionQueue()

queue.enqueue(10)
queue.showData()

queue.enqueue(20)
queue.showData()

queue.enqueue(30)
queue.showData()

a1 = queue.dequeue()
print(a1, end=' - ')
queue.showData()

a1 = queue.dequeue()
print(a1, end=' - ')
queue.showData()

a1 = queue.dequeue()
print(a1, end=' - ')
queue.showData()
# Out:
# [10]
# [10, 20]
# [10, 20, 30]
# 10 - [20, 30]
# 20 - [30]
# 30 - []

# %%
linkedList = LikeLionLinkedList()

linkedList.addData(10)
linkedList.showData()

linkedList.addData(20)
linkedList.showData()

linkedList.addData(30)
linkedList.showData()

a1 = linkedList.getData(0)
print(a1)

a2 = linkedList.getData(1)
print(a2)

linkedList.setData(100, 1)
linkedList.showData()

linkedList.insertData(200, 1)
linkedList.showData()

linkedList.deleteData(1)
linkedList.showData()
# Out:
# [10]
# [10, 20]
# [10, 20, 30]
# 10
# 20
# [10, 100, 30]
# [10, 200, 100, 30]
# [10, 100, 30]
