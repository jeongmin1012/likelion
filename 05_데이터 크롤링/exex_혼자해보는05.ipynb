# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.support.ui import Select
import numpy as np
import pandas as pd

# %%
# 웹드라이버 실행
driver = webdriver.Chrome()

# %%
# 사이트를 요청한다.
driver.get('https://m.sports.naver.com/kbaseball/schedule/index?date=2021-05-01')

# %%
year_tag = driver.find_element(by=By.CSS_SELECTOR, value = '#content > div > div:nth-child(3) > div > div.CalendarDate_calendar_date_group__bXTAD > div > div.CalendarDate_current_date_wrap__BSh44 > time > span')
score_board = driver.find_element(by=By.CSS_SELECTOR, value = '#content > div > div:nth-child(4) > div > ul')
bb_score = score_board.find_elements(by=By.CSS_SELECTOR, value = ':scope > li')

for score in bb_score:
    away_team = score.find_element(by=By.CSS_SELECTOR,value = ' div > div.MatchBox_match_area__GzOFv > div.MatchBoxHeadToHeadArea_team_item__9ZknX.MatchBoxHeadToHeadArea_type_winner__IpaWH')
    home_team = score.find_element(by=By.CSS_SELECTOR,value =' div > div.MatchBox_match_area__GzOFv > div.MatchBoxHeadToHeadArea_team_item__9ZknX.MatchBoxHeadToHeadArea_type_loser__-pMdX')
# Out:
# ---------------------------------------------------------------------------
# InvalidSelectorException                  Traceback (most recent call last)
# Cell In[15], line 7
#       5 for score in bb_score:
#       6     teams = score.find_elements(By.CSS_SELECTOR, 'div.MatchBoxHeadToHeadArea_team_item__9ZknX')
# ----> 7     scores = score.find_elements(By.CSS_SELECTOR, 'div.MatchBoxScore_score__...')
#       9     home_team = teams[0].text
#      10     away_team = teams[1].text
#
# File ~/miniconda3/envs/data/lib/python3.13/site-packages/selenium/webdriver/remote/webelement.py:558, in WebElement.find_elements(self, by, value)
#     536 """Find elements given a By strategy and locator.
#     537
#     538 Args:
#    (...)    555     element = driver.find_elements(By.ID, "foo")
#     556 """
#     557 by, value = self._parent.locator_converter.convert(by, value)
# --> 558 return self._execute(Command.FIND_CHILD_ELEMENTS, {"using": by, "value": value})["value"]
#
# ...
